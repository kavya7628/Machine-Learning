# %%
import pandas as pd
df = pd.read_csv("/Users/kavyakatumbaka/Documents/GitHub/Machine-Learning/DecisionTree/ExercisingDataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dropna(inplace=True)

# %%
Survived = df[df.Survived == 1]
Survived.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S
# 21      0    248698  13.0000   D56        S

# %%
dead =df[df.Survived == 0]
dead.head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 27           28         0       1  Fortune, Mr. Charles Alexander  male  19.0
# 54           55         0       1  Ostby, Mr. Engelhart Cornelius  male  65.0
# 62           63         0       1     Harris, Mr. Henry Birkhardt  male  45.0
# 75           76         0       3         Moen, Mr. Sigurd Hansen  male  25.0
#
#     SibSp  Parch  Ticket      Fare        Cabin Embarked
# 6       0      0   17463   51.8625          E46        S
# 27      3      2   19950  263.0000  C23 C25 C27        S
# 54      0      1  113509   61.9792          B30        C
# 62      1      0   36973   83.4750          C83        S
# 75      0      0  348123    7.6500        F G73        S

# %%
df.groupby('Survived').mean()
# Out:
# /var/folders/z8/6r8tz89j47lgz6fnw7d3vbqh0000gn/T/ipykernel_21892/1397368861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          402.983333  1.216667  41.350000  0.366667  0.450000  64.048262
# 1          480.918699  1.178862  32.905854  0.512195  0.487805  85.821107

# %%
inputs = df.drop(['PassengerId', 'Survived', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], 'columns')
target = df['Survived']
# Out:
# /var/folders/z8/6r8tz89j47lgz6fnw7d3vbqh0000gn/T/ipykernel_21892/1045309372.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs = df.drop(['PassengerId', 'Survived', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], 'columns')

# %%
inputs.head()
target.head()
# Out:
# 1     1
# 3     1
# 6     0
# 10    1
# 11    1
# Name: Survived, dtype: int64

# %%
inputs.head()
# Out:
#     Pclass     Sex   Age     Fare
# 1        1  female  38.0  71.2833
# 3        1  female  35.0  53.1000
# 6        1    male  54.0  51.8625
# 10       3  female   4.0  16.7000
# 11       1  female  58.0  26.5500

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_sex = LabelEncoder()

# %%
inputs['sex_n'] = le_sex.fit_transform(inputs['Sex'])

# %%
inputs.head()
# Out:
#     Pclass     Sex   Age     Fare  sex_n
# 1        1  female  38.0  71.2833      0
# 3        1  female  35.0  53.1000      0
# 6        1    male  54.0  51.8625      1
# 10       3  female   4.0  16.7000      0
# 11       1  female  58.0  26.5500      0

# %%
Finput = inputs.drop(['Sex'], axis = 'columns')

# %%
Finput.head()
# Out:
#     Pclass   Age     Fare  sex_n
# 1        1  38.0  71.2833      0
# 3        1  35.0  53.1000      0
# 6        1  54.0  51.8625      1
# 10       3   4.0  16.7000      0
# 11       1  58.0  26.5500      0

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
model = tree.DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(Finput, target, test_size = 0.2)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.8378378378378378
